# %% [markdown]
# ## Select / download video

# %%
# !pip install yt-dlp moviepy openai-whisper==20230124 whisper-timestamped
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2024.12.6-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Collecting openai-whisper==20230124
#   Downloading openai-whisper-20230124.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting whisper-timestamped
#   Downloading whisper_timestamped-1.15.8-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230124) (1.26.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230124) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230124) (4.66.6)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230124) (10.5.0)
# Requirement already satisfied: transformers>=4.19.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20230124) (4.46.3)
# Collecting ffmpeg-python==0.2.0 (from openai-whisper==20230124)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python==0.2.0->openai-whisper==20230124) (1.0.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.36.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.5.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from whisper-timestamped) (3.0.11)
# Collecting dtw-python (from whisper-timestamped)
#   Downloading dtw_python-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (11.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio_ffmpeg>=0.2.0->moviepy) (75.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (0.26.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.19.0->openai-whisper==20230124) (0.4.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dtw-python->whisper-timestamped) (1.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230124) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230124) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230124) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230124) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20230124) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->openai-whisper==20230124) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20230124) (3.0.2)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading yt_dlp-2024.12.6-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 64.4 MB/s eta 0:00:00
# Downloading whisper_timestamped-1.15.8-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 4.6 MB/s eta 0:00:00
# Downloading dtw_python-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.7/764.7 kB 44.4 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (setup.py) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20230124-py3-none-any.whl size=1179308 sha256=0abd1cde923f07e5dac9ab50448ff44ea5077789d7db0bc26d79eaf04fec5720
#   Stored in directory: /root/.cache/pip/wheels/ed/9c/6d/9df9e633b11625901f05fbf6b7bb89aa365705be1f1aa65c7d
# Successfully built openai-whisper
# Installing collected packages: yt-dlp, ffmpeg-python, dtw-python, openai-whisper, whisper-timestamped
# Successfully installed dtw-python-1.5.3 ffmpeg-python-0.2.0 openai-whisper-20230124 whisper-timestamped-1.15.8 yt-dlp-2024.12.6

# %%
# !cd /content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt
# Out:
# /bin/bash: line 1: cd: /content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt: No such file or directory

# %%
import os
import json
import numpy as np
import whisper_timestamped
from moviepy.editor import VideoFileClip
import yt_dlp
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/sliders.py:61: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if event.key is 'enter':

# %%
def download_audio_from_youtube(url):
    try:
        ydl_opts = {
            'format': 'bestaudio/best',
            'outtmpl': '%(id)s.%(ext)s',
            'postprocessors': [{
                'key': 'FFmpegExtractAudio',
                'preferredcodec': 'wav',
                'preferredquality': '192'
            }],
            'noplaylist': True,
        }

        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(url, download=True)
            audio_file = f"{info_dict['id']}.wav"
            return audio_file

    except Exception as e:
        return str(e)

# %%
def extract_audio_from_video(video_file):
    try:
        audio_file = "extracted_audio.wav"
        video_clip = VideoFileClip(video_file)
        video_clip.audio.write_audiofile(audio_file, codec='pcm_s16le', ffmpeg_params=["-ac", "1", "-ar", "16000"])
        return audio_file

    except Exception as e:
        return str(e)

# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from pydub import AudioSegment

# %%
def process_audio(audio_file):
    try:
        print("Processing audio file:", os.path.abspath(audio_file))
        if not os.path.exists(audio_file):
            return "Audio file does not exist."
        audio = AudioSegment.from_file(audio_file)
        duration_ms = 3 * 60 * 1000
        audio = audio[:duration_ms]

        temp_file = "temp_audio.wav"
        audio.export(temp_file, format="wav")

        audio = whisper_timestamped.load_audio(temp_file)
        audio = audio / np.max(np.abs(audio))
        model = whisper_timestamped.load_model("base", device="cpu")
        result = whisper_timestamped.transcribe(model, audio, vad = True, language="en")

        # Save results to SRT file
        writer = whisper_timestamped.utils.get_writer("srt", ".")
        writer(result, "output")
        print(f"SRT file saved: output.srt")

        # Save results to JSON file
        json_output_file = "output.json"
        with open(json_output_file, 'w', encoding='utf-8') as json_file:
            json.dump(result, json_file, indent=2, ensure_ascii=False)
        print(f"JSON file saved: {json_output_file}")

        return "Transcription completed"

    except Exception as e:
        return str(e)

# %% [markdown]
# Use Youtube link

# %%
youtube_url = 'https://www.youtube.com/watch?v=RE-dLbNOkf4&list=PLZWl0Mna08lURclW-dxqitxEeUt3EiLhQ'  # Change this to YouTube URL
audio_file = download_audio_from_youtube(youtube_url)
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/watch?v=RE-dLbNOkf4&list=PLZWl0Mna08lURclW-dxqitxEeUt3EiLhQ
# [youtube:tab] Downloading just the video RE-dLbNOkf4 because of --no-playlist
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RE-dLbNOkf4
# [youtube] RE-dLbNOkf4: Downloading webpage
# [youtube] RE-dLbNOkf4: Downloading ios player API JSON
# [youtube] RE-dLbNOkf4: Downloading mweb player API JSON
# [youtube] RE-dLbNOkf4: Downloading m3u8 information
# [info] RE-dLbNOkf4: Downloading 1 format(s): 251
# [download] Destination: RE-dLbNOkf4.webm
# [download] 100% of  422.05KiB in 00:00:00 at 1.50MiB/s
# [ExtractAudio] Destination: RE-dLbNOkf4.wav
# Deleting original file RE-dLbNOkf4.webm (pass -k to keep)

# %%
if audio_file:
    result = process_audio(audio_file)
    print(result)
# Out:
# Processing audio file: /content/RE-dLbNOkf4.wav
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/whisper/__init__.py:115: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
#
# WARNING:whisper_timestamped:Please install onnxruntime to use more efficiently silero VAD
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/torch/hub.py:330: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
#
# Downloading: "https://github.com/snakers4/silero-vad/zipball/master" to /root/.cache/torch/hub/master.zip
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:76: UserWarning: Performing inference on CPU when CUDA is available
#   warnings.warn("Performing inference on CPU when CUDA is available")
#
# 100%|██████████| 3003/3003 [00:13<00:00, 227.95frames/s]
# SRT file saved: output.srt
# JSON file saved: output.json
# Transcription completed

# %%
import shutil
import os

def save_json_to_directory(source_file, target_directory):
    try:
        # Ensure the target directory exists
        if not os.path.exists(target_directory):
            os.makedirs(target_directory)

        # Define the destination path
        destination_file = os.path.join(target_directory, os.path.basename(source_file))

        # Copy the file to the target directory
        shutil.copy(source_file, destination_file)

        print(f"File copied to: {destination_file}")
        return destination_file

    except Exception as e:
        print(f"Error: {e}")
        return None

# Example usage
source_file = "output.json"  # Path of the existing JSON file
target_directory = "/content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt/jersey"  # Replace with your directory
save_json_to_directory(source_file, target_directory)
# Out:
# File copied to: /content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt/jersey/output.json
# '/content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt/jersey/output.json'

# %% [markdown]
# Use local path

# %% [markdown]
# ## Extract timestamp for each word

# %%
import json
import re

# %%
file_path = '/content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt/jersey/output.json'

with open(file_path, 'r') as file:
    data = json.load(file)

print(data["text"])
# Out:
#  At Jersey mics, they slice your order fresh right in front of you. And let me tell you, watch in that, can send a rush of emotions through a person. Excitement, impatience, baby-like wonder, indecisive, anticipatory chewing, nerves pacing, happy claps, and finally jealousy, because that's this guy's self. I should order one. Good idea. Slice right in front of you. To Jersey mics thing, a sub above.

# %%
# This function is to lowracse whole text, easier to re-match and contain big letter "I"
def lowercase(text):
    exceptions = {"I", "I'm", "I'll", "I've", "I'd"}
    words = re.findall(r"\b\w+'\w+|\b\w+\b|[^\w\s]", text)
    # processed_words = [
    #     word if word in exceptions else word.lower()
    #     for word in words
    # ]
    result = " ".join(words)
    # result = re.sub(r'([?.!,:;])\s*', r'\1 ', result)
    # result = re.sub(r'\s([?.!,:;])', r'\1', result)

    return result

# %%
data["text"] = lowercase(data["text"])
print(data["text"])
# Out:
# At Jersey mics , they slice your order fresh right in front of you . And let me tell you , watch in that , can send a rush of emotions through a person . Excitement , impatience , baby - like wonder , indecisive , anticipatory chewing , nerves pacing , happy claps , and finally jealousy , because that's this guy's self . I should order one . Good idea . Slice right in front of you . To Jersey mics thing , a sub above .

# %%
# Extract the desired features
word_timings = []
for segment in data['segments']:
    for word in segment['words']:
        word_timing = {
            'text': lowercase(word['text']),
            'start': word['start'],
            'end': word['end']
        }
        word_timings.append(word_timing)

# Print the total number of words extracted
print(f"Total words extracted: {len(word_timings)}")

# Print the last few entries to verify
print("Last 5 entries:")
for entry in word_timings[:10]:
    print(entry)

# Optionally, save to a new JSON file
with open('extracted_word_timings.json', 'w') as outfile:
    json.dump(word_timings, outfile, indent=2)

print("Extracted data saved to 'extracted_word_timings.json'")
# Out:
# Total words extracted: 68
# Last 5 entries:
# {'text': 'At', 'start': 0.24, 'end': 0.36}
# {'text': 'Jersey', 'start': 0.36, 'end': 0.8}
# {'text': 'mics ,', 'start': 0.8, 'end': 1.22}
# {'text': 'they', 'start': 1.48, 'end': 1.66}
# {'text': 'slice', 'start': 1.66, 'end': 2.0}
# {'text': 'your', 'start': 2.0, 'end': 2.26}
# {'text': 'order', 'start': 2.26, 'end': 2.52}
# {'text': 'fresh', 'start': 2.52, 'end': 3.12}
# {'text': 'right', 'start': 3.12, 'end': 3.62}
# {'text': 'in', 'start': 3.62, 'end': 3.8}
# Extracted data saved to 'extracted_word_timings.json'

# %% [markdown]
# ## LLM segamentation

# %%
# Import the Python SDK
import google.generativeai as genai

genai.configure(api_key='AIzaSyB2ApAg4Dk5ctVmhR0XHCKRv6dMGIrCtts')

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
text = data["text"]

# %%
# Segmentation function
def segment_text_gemini(model, text):
    prompt = f"""
    You are a helpful assistant. Your task is to segment sentences which is longer than 65 characters,
    including spaces and punctuation, into shorter sentences.
    Each segmented sentence MUST NOT exceed 65 characters.
    Each segmented sentence must be independent, complete, and clear, suitable for direct translation or subtitle creation.
    NOTE: All connecting words (e.g., where, which, and, but, that) MUST remain intact. They should NOT be omitted,
    split, or modified in any way.

    Example:
    Input:
    so one of the biggest challenges when talking about anything related to mental health whether
    depression mental illness addiction is it can sometimes be really hard to explain how can you want something
    Output:
    so one of the biggest challenges when talking about
    anything related to mental health
    whether depression mental illness addiction
    is it can sometimes be really hard to explain
    how can you want something:{text}
    """

    # Send request to model
    response = model.generate_content(prompt, generation_config=genai.types.GenerationConfig(temperature=0.0))
    print(response)
    return response.text

# Get segmented text
segmented_output = segment_text_gemini(model, text)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "At Jersey mics, they slice your order fresh.\nRight in front of you.\nAnd let me tell you, watch that.\nIt can send a rush of emotions through a person.\nExcitement, impatience, baby-like wonder.\nIndecisive, anticipatory chewing, nerves pacing.\nHappy claps, and finally jealousy.\nBecause that's this guy's self.\nI should order one.\nGood idea.\nSlice right in front of you.\nTo Jersey mics thing, a sub above.\n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "citation_metadata": {
#             "citation_sources": [
#               {
#                 "start_index": 104,
#                 "end_index": 230,
#                 "uri": "https://archive.org/details/CNNW_20221028_120000_New_Day_With_John_Berman_and_Brianna_Keilar"
#               }
#             ]
#           },
#           "avg_logprobs": -0.007428916724952492
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 285,
#         "candidates_token_count": 111,
#         "total_token_count": 396
#       }
#     }),
# )

# %%
prompt = f"""
    You are a helpful assistant. Your task is to segment sentences which is
    longer than 65 characters, including spaces and punctuation, into shorter
    sentences. Each segmented sentence MUST NOT exceed 65 characters.
    Each segmented sentence must be independent, complete, and clear, suitable
    for direct translation or subtitle creation.
    NOTE: All connecting words (e.g., where, which, and, but, that) MUST remain
    intact. They should NOT be omitted, split, or modified in any way.

    Example:
    Input:
    so one of the biggest challenges when talking about anything related to
    mental health whether depression mental illness addiction is it can
    sometimes be really hard to explain how can you want something
    Output:
    so one of the biggest challenges when talking about
    anything related to mental health
    whether depression mental illness addiction
    is it can sometimes be really hard to explain
    how can you want something:{text}
    """

# %%
print(segmented_output)
# Out:
# At Jersey mics, they slice your order fresh.
# Right in front of you.
# And let me tell you, watch that.
# It can send a rush of emotions through a person.
# Excitement, impatience, baby-like wonder.
# Indecisive, anticipatory chewing, nerves pacing.
# Happy claps, and finally jealousy.
# Because that's this guy's self.
# I should order one.
# Good idea.
# Slice right in front of you.
# To Jersey mics thing, a sub above.

# %% [markdown]
# ## Re-match timestamp

# %%
output_sentences = segmented_output.split("\n")

# %%
output_sentences
# Out:
# ['At Jersey mics, they slice your order fresh.',
#  'Right in front of you.',
#  'And let me tell you, watch that.',
#  'It can send a rush of emotions through a person.',
#  'Excitement, impatience, baby-like wonder.',
#  'Indecisive, anticipatory chewing, nerves pacing.',
#  'Happy claps, and finally jealousy.',
#  "Because that's this guy's self.",
#  'I should order one.',
#  'Good idea.',
#  'Slice right in front of you.',
#  'To Jersey mics thing, a sub above.',
#  '']

# %%
# Clean the text to match the word
cleaned_output = []
for sentence in output_sentences:
  sentence = re.sub(r'[,.!?]', '', sentence)
  cleaned_output.append(lowercase(sentence))

# %%
result = []
current_id = 0

for sentence in cleaned_output:
    words = sentence.split()
    num_words = len(words)

    if num_words == 0:
        continue

    start_word_id = current_id + 1
    end_word_id = current_id + num_words

    print(f"Processing sentence: '{sentence}'")
    print(f"Total words in sentence: {num_words}, Current total words: {current_id}")

    if start_word_id > len(word_timings) or end_word_id > len(word_timings):
        print(f"Warning: Index out of range. start_word_id: {start_word_id}, end_word_id: {end_word_id}")
        print(f"word_timings length: {len(word_timings)}")
        continue
    try:
        start_time = word_timings[start_word_id - 1]['start']
        end_time = word_timings[end_word_id - 1]['end']
    except IndexError as e:
        print(f"Error: Index error when accessing word_timings. {e}")
        continue

    result.append({
        'sentence': sentence,
        'start': start_time,
        'end': end_time
    })

    current_id += num_words
# Out:
# Processing sentence: 'At Jersey mics they slice your order fresh'
# Total words in sentence: 8, Current total words: 0
# Processing sentence: 'Right in front of you'
# Total words in sentence: 5, Current total words: 8
# Processing sentence: 'And let me tell you watch that'
# Total words in sentence: 7, Current total words: 13
# Processing sentence: 'It can send a rush of emotions through a person'
# Total words in sentence: 10, Current total words: 20
# Processing sentence: 'Excitement impatience baby - like wonder'
# Total words in sentence: 6, Current total words: 30
# Processing sentence: 'Indecisive anticipatory chewing nerves pacing'
# Total words in sentence: 5, Current total words: 36
# Processing sentence: 'Happy claps and finally jealousy'
# Total words in sentence: 5, Current total words: 41
# Processing sentence: 'Because that's this guy's self'
# Total words in sentence: 5, Current total words: 46
# Processing sentence: 'I should order one'
# Total words in sentence: 4, Current total words: 51
# Processing sentence: 'Good idea'
# Total words in sentence: 2, Current total words: 55
# Processing sentence: 'Slice right in front of you'
# Total words in sentence: 6, Current total words: 57
# Processing sentence: 'To Jersey mics thing a sub above'
# Total words in sentence: 7, Current total words: 63
# Warning: Index out of range. start_word_id: 64, end_word_id: 70
# word_timings length: 68

# %%
for entry in result[:5]:
    print(entry)
# Out:
# {'sentence': 'At Jersey mics they slice your order fresh', 'start': 0.24, 'end': 3.12}
# {'sentence': 'Right in front of you', 'start': 3.12, 'end': 4.28}
# {'sentence': 'And let me tell you watch that', 'start': 4.42, 'end': 5.94}
# {'sentence': 'It can send a rush of emotions through a person', 'start': 5.94, 'end': 8.78}
# {'sentence': 'Excitement impatience baby - like wonder', 'start': 9.18, 'end': 14.96}

# %% [markdown]
# # Transform into .SRT

# %%
def format_time(seconds):
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{hours:02}:{minutes:02}:{secs:02},{milliseconds:03}"

# %%
def generate_srt(data):
    srt_lines = []
    for index, item in enumerate(data):
        start_time = format_time(item['start'])
        end_time = format_time(item['end'])
        sentence = item['sentence']

        srt_lines.append(f"{index + 1}")
        srt_lines.append(f"{start_time} --> {end_time}")
        srt_lines.append(sentence)
        srt_lines.append("")

    return "\n".join(srt_lines)

# %%
import os

def save_srt(directory, filename, srt_content):
    try:
        # Ensure the directory exists
        if not os.path.exists(directory):
            os.makedirs(directory)

        # Construct the full path for the file
        file_path = os.path.join(directory, filename)

        # Write the SRT content to the file
        with open(file_path, "w", encoding="utf-8") as file:
            file.write(srt_content)

        print(f"SRT file saved: {file_path}")
        return file_path

    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
srt_content = generate_srt(result)
directory = "/content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt"
save_srt(directory, "jersey.srt", srt_content)

# print("SRT file has been saved as 'output.srt'")
# Out:
# SRT file saved: /content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt/jersey.srt
# '/content/drive/MyDrive/NLP/TranscribeAI/Gemini_srt/jersey.srt'
