# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NLP/TranscribeAI/
# Out:
# /content/drive/MyDrive/NLP/TranscribeAI

# %%
import json

# Specify the path to your JSON file
file_path = '/content/drive/MyDrive/NLP/TranscribeAI/whisper_jsons/part10.json'

# Open and read the JSON file
with open(file_path, 'r') as file:
    data = json.load(file)

# Print the contents of the JSON file
data["text"]
# Out:
# " Hello and welcome back to my therapist plays disco elisium analysis series. On today's episode we're going to address something kind of unavoidable in a game like this, which is what are some of the crossovers between politics and mental health and kind of some personal struggles I have about integrating those two subjects. I'm sure there will be a lot of discussion about this in the comments, just know that this is all recorded previously. I think I'm going to probably make a dedicated video at some point kind of like compiling my thoughts a little more, but yeah, to get an early look at kind of where my, my, my, my stomach's going to be problemless. Aside from that, we have a very special moment in this episode, which is finally we're going to reach the end of our first day as a detective. It's taken us a while and we're going to take another look at how Kim and I's relationship has been developing over this very challenging day and see if there's actually some things that we've become like close on. So, all that's coming up, I'm excited to get into it. Let's do it. Alrighty, we are going to talk to Kim. We should think about calling it today maybe. The nights are still miserably cold this time of year. I haven't paid the cafeteria manager for the damages yet. Should take care of that then. I don't have the money. I'm stuck to him anyway. An office of the RCM shouldn't be sleeping in the street. We'll figure something out. Though he finds this situation frustrating, he is doing his best to not make you feel any worse than you already do. I respect that, Kim. He's, he's, Kim is one of a lot of points with me this, in these chapters of our stream. Okay, let's see if we can reason with this gentleman. Can I help you? But I don't have another option here. Yes, have you got it? Can we come to some sort of arrangement? Does that arrangement include you paying me what we already agreed you owe me? Kim is about to say something. Let him. Let's do that. I understand your predicament as the manager. However, I feel I must remind you that we are here to conduct an important investigation that also affects your business. That's a good point. Put the squeeze on him. Give me for saying this, but your colleagues seems more committed to drinking and... He stops me in sentence. He shrinks back a bit under the Lieutenant-Severge's. I mean no effects. It's really nothing personal. I just have to protect the interests of this establishment. No, kiddie. Kiddie."

# %%
# Extract the desired features


word_timings = []
for segment in data['segments']:
    for word in segment['words']:
        word_timing = {
            'text': word['text'],
            'start': word['start'],
            'end': word['end']
        }
        word_timings.append(word_timing)

# Print the total number of words extracted
print(f"Total words extracted: {len(word_timings)}")

# Print the last few entries to verify
print("Last 5 entries:")
for entry in word_timings[:10]:
    print(entry)

# Optionally, save to a new JSON file
with open('extracted_word_timings.json', 'w') as outfile:
    json.dump(word_timings, outfile, indent=2)

print("Extracted data saved to 'extracted_word_timings.json'")
# Out:
# Total words extracted: 455
# Last 5 entries:
# {'text': 'Hello', 'start': 0.58, 'end': 0.78}
# {'text': 'and', 'start': 0.78, 'end': 1.44}
# {'text': 'welcome', 'start': 1.44, 'end': 1.62}
# {'text': 'back', 'start': 1.62, 'end': 1.82}
# {'text': 'to', 'start': 1.82, 'end': 2.0}
# {'text': 'my', 'start': 2.0, 'end': 2.22}
# {'text': 'therapist', 'start': 2.22, 'end': 2.62}
# {'text': 'plays', 'start': 2.62, 'end': 2.96}
# {'text': 'disco', 'start': 2.96, 'end': 3.32}
# {'text': 'elisium', 'start': 3.32, 'end': 3.84}
# Extracted data saved to 'extracted_word_timings.json'

# %%
# captions_list = []

# for i,segment in enumerate(data["segments"]):
#   #print(segment["text"])
#   # print(segment["words"])
#   captions_list.append(segment["text"])

# %%
import re

def split_long_segments(captions, max_words=8, gap_threshold=1.0):
    refined_captions = []

    for caption in captions:
        words = caption['text'].split()
        start_time = caption['start']
        end_time = caption['end']
        duration = end_time - start_time

        # Split text into phrases using punctuation as natural break points
        phrases = re.split(r'([.,!?])', caption['text'])
        phrases = [''.join(x).strip() for x in zip(phrases[0::2], phrases[1::2])] + [phrases[-1]] if len(phrases) > 1 else [phrases[0]]

        phrase_start = start_time
        word_time = duration / len(words) if len(words) > 0 else 0

        for phrase in phrases:
            phrase_words = phrase.split()
            phrase_duration = word_time * len(phrase_words)
            phrase_end = phrase_start + phrase_duration

            # If phrase exceeds max_words, split it further
            for i in range(0, len(phrase_words), max_words):
                sub_phrase_words = phrase_words[i:i + max_words]
                sub_phrase_start = phrase_start + i * word_time
                sub_phrase_end = min(phrase_start + (i + max_words) * word_time, phrase_end)

                refined_captions.append({
                    'start': sub_phrase_start,
                    'end': sub_phrase_end,
                    'sentence': ' '.join(sub_phrase_words)
                })

            phrase_start = phrase_end

    # Incorporate pauses
    final_captions = []
    for i, caption in enumerate(refined_captions):
        # Add a pause gap if necessary
        if i > 0 and caption['start'] - refined_captions[i - 1]['end'] > gap_threshold:
            final_captions.append({
                'start': refined_captions[i - 1]['end'],
                'end': caption['start'],
                'sentence': ''
            })
        # Append the current caption
        final_captions.append(caption)

    return final_captions

# %%
captions_dict = split_long_segments(data["segments"])

# %% [markdown]
# # Transform into .SRT

# %%
# Clean the text to match the word
cleaned_output = []
for sentence in captions_dict:
  cleaned = sentence["sentence"] #re.sub(r'[,.!?]', '', sentence)
  cleaned_output.append(cleaned)

# %%
result = []
current_id = 0

for sentence in cleaned_output:
    words = sentence.split()
    num_words = len(words)

    if num_words == 0:
        continue

    start_word_id = current_id + 1
    end_word_id = current_id + num_words # So this can still match the time even when the last word is not complete haha
    try:
      start_time = word_timings[start_word_id - 1]['start']
      end_time = word_timings[end_word_id - 1]['end']
    except:
      start_word_id = current_id + 1 - (2)
      end_word_id = current_id + num_words-(2)
      # print(start_word_id)
      # print(end_word_id)
      # print(len(word_timings))
      # print("except")
      start_time = word_timings[start_word_id - 1]['start']
      end_time = word_timings[end_word_id - 1]['end']
    result.append({
        'sentence': sentence,
        'start': start_time,
        'end': end_time
    })

    current_id += num_words

# %%
def format_time(seconds):
    hours = int(seconds // 3600)
    minutes = int((seconds % 3600) // 60)
    secs = int(seconds % 60)
    milliseconds = int((seconds - int(seconds)) * 1000)
    return f"{hours:02}:{minutes:02}:{secs:02},{milliseconds:03}"

# %%
def generate_srt(data):
    srt_lines = []
    for index, item in enumerate(data):
        start_time = format_time(item['start'])
        end_time = format_time(item['end'])
        sentence = item['sentence']

        srt_lines.append(f"{index + 1}")
        srt_lines.append(f"{start_time} --> {end_time}")
        srt_lines.append(sentence)
        srt_lines.append("")

    return "\n".join(srt_lines)

# %%
def save_srt(filename, srt_content):
    with open(filename, "w", encoding="utf-8") as file:
        file.write(srt_content)

# %%
srt_content = generate_srt(result)

save_srt("Segment_fn_srt/captions_part10.srt", srt_content)

print("SRT file has been saved")# as 'Segment_fn_srt/captions_analysis3.srt'")
# Out:
# SRT file has been saved

# %%
# !sudo apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import time

# Start timing the conversion process
start_time = time.time()

# Run the ffmpeg command with the updated subtitle style
# !ffmpeg -i video.mp4 -i Gemini_async/srts/pa.srt -c:v libx264 -vf "subtitles=captions_srt_output.srt:force_style='Fontname=Tahoma,Fontsize=24,PrimaryColour=&H0018B2FF& ,SecondaryColour=&H00FFFFFF& ,BorderStyle=1,Outline=1.0,Shadow=0.0'" caption_videos/part3.mp4

# Calculate and print the elapsed time
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Conversion took {elapsed_time/60:.2f} mins.")
# Out:
# Streaming output truncated to the last 5000 lines.
# [libx264 @ 0x5b023d3a0680] frame=25462 QP=23.31 NAL=0 Slice:B Poc:142 I:30   P:205  SKIP:685  size=825 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25463 QP=19.88 NAL=2 Slice:P Poc:152 I:28   P:421  SKIP:471  size=2553 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:12 poc:312/312 ref:3/1 qp:26 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:13 poc:314/314 ref:3/1 qp:26 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25464 QP=24.56 NAL=2 Slice:B Poc:148 I:3    P:287  SKIP:630  size=712 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:14 poc:316/316 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25465 QP=25.93 NAL=0 Slice:B Poc:146 I:10   P:192  SKIP:718  size=372 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25466 QP=27.36 NAL=0 Slice:B Poc:150 I:3    P:231  SKIP:686  size=468 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:15 poc:318/318 ref:3/1 qp:28 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:0 poc:320/320 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25467 QP=21.18 NAL=2 Slice:P Poc:160 I:39   P:385  SKIP:496  size=2916 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:1 poc:322/322 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25468 QP=25.65 NAL=2 Slice:B Poc:156 I:11   P:318  SKIP:591  size=1092 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:2 poc:324/324 ref:3/1 qp:28 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25469 QP=25.20 NAL=0 Slice:B Poc:154 I:6    P:224  SKIP:690  size=525 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:3 poc:326/326 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25470 QP=28.83 NAL=0 Slice:B Poc:158 I:10   P:235  SKIP:675  size=678 bytes
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:4 poc:328/328 ref:3/1 qp:26 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25471 QP=21.33 NAL=2 Slice:P Poc:162 I:20   P:317  SKIP:583  size=2051 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:5 poc:330/330 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25472 QP=21.50 NAL=2 Slice:P Poc:170 I:31   P:352  SKIP:537  size=2152 bytes
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:6 poc:332/332 ref:3/1 qp:28 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25473 QP=25.80 NAL=2 Slice:B Poc:166 I:4    P:280  SKIP:636  size=894 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:7 poc:334/334 ref:3/1 qp:29 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25474 QP=26.27 NAL=0 Slice:B Poc:164 I:3    P:227  SKIP:690  size=469 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 6(SEI), nal_ref_idc: 0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 5(IDR), nal_ref_idc: 3
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 I fix IDR frame:0 poc:0/0 ref:0/0 qp:25 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25475 QP=25.08 NAL=0 Slice:B Poc:168 I:4    P:223  SKIP:693  size=456 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:1 poc:2/2 ref:1/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25476 QP=20.65 NAL=2 Slice:P Poc:178 I:37   P:367  SKIP:516  size=2587 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:2 poc:4/4 ref:2/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25477 QP=25.22 NAL=2 Slice:B Poc:174 I:7    P:325  SKIP:588  size=1084 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:3 poc:6/6 ref:3/1 qp:28 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25478 QP=26.46 NAL=0 Slice:B Poc:172 I:6    P:230  SKIP:684  size=619 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25479 QP=28.60 NAL=0 Slice:B Poc:176 I:3    P:230  SKIP:687  size=492 bytes
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:4 poc:8/8 ref:3/1 qp:29 loop:1:0:0 weight:0
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:5 poc:10/10 ref:3/1 qp:28 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25480 QP=21.87 NAL=2 Slice:P Poc:180 I:13   P:301  SKIP:606  size=1566 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:6 poc:12/12 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25481 QP=22.66 NAL=2 Slice:P Poc:182 I:17   P:288  SKIP:615  size=1777 bytes
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:7 poc:14/14 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25482 QP=20.04 NAL=2 Slice:P Poc:190 I:44   P:379  SKIP:497  size=3378 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:8 poc:16/16 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25483 QP=25.27 NAL=2 Slice:B Poc:186 I:11   P:293  SKIP:616  size=1179 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:9 poc:18/18 ref:3/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25484 QP=26.30 NAL=0 Slice:B Poc:184 I:5    P:238  SKIP:677  size=564 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:10 poc:20/20 ref:3/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25485 QP=26.79 NAL=0 Slice:B Poc:188 I:2    P:222  SKIP:696  size=483 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:11 poc:22/22 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25486 QP=20.11 NAL=2 Slice:P Poc:198 I:54   P:370  SKIP:496  size=3426 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:12 poc:24/24 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25487 QP=25.29 NAL=2 Slice:B Poc:194 I:2    P:286  SKIP:632  size=852 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:13 poc:26/26 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25488 QP=27.58 NAL=0 Slice:B Poc:192 I:0    P:213  SKIP:707  size=459 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:14 poc:28/28 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25489 QP=24.60 NAL=0 Slice:B Poc:196 I:0    P:208  SKIP:712  size=371 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:15 poc:30/30 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25490 QP=20.83 NAL=2 Slice:P Poc:204 I:24   P:361  SKIP:535  size=2919 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:0 poc:32/32 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25491 QP=25.77 NAL=2 Slice:B Poc:200 I:2    P:230  SKIP:688  size=557 bytes
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:1 poc:34/34 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25492 QP=25.64 NAL=0 Slice:B Poc:202 I:0    P:219  SKIP:701  size=416 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:2 poc:36/36 ref:3/1 qp:27 loop:1:0:0 weight:0
# [Parsed_subtitles_0 @ 0x5b023d32df40] line break at 31
# [libx264 @ 0x5b023d3a0680] frame=25493 QP=21.26 NAL=2 Slice:P Poc:212 I:33   P:360  SKIP:527  size=3068 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [Parsed_subtitles_0 @ 0x5b023d32df40] Change happened at time ms:1065272.541667
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:3 poc:38/38 ref:3/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25494 QP=25.19 NAL=2 Slice:B Poc:208 I:2    P:273  SKIP:645  size=716 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:4 poc:40/40 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25495 QP=27.65 NAL=0 Slice:B Poc:206 I:0    P:187  SKIP:733  size=355 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:5 poc:42/42 ref:3/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25496 QP=23.31 NAL=0 Slice:B Poc:210 I:1    P:197  SKIP:722  size=371 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:6 poc:44/44 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25497 QP=20.73 NAL=2 Slice:P Poc:216 I:27   P:323  SKIP:570  size=2213 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:7 poc:46/46 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25498 QP=23.82 NAL=0 Slice:B Poc:214 I:0    P:191  SKIP:729  size=346 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:8 poc:48/48 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25499 QP=19.44 NAL=2 Slice:P Poc:224 I:42   P:416  SKIP:462  size=2976 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:9 poc:50/50 ref:3/1 qp:27 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=25500 QP=24.58 NAL=2 Slice:B Poc:220 I:2    P:330  SKIP:588  size=735 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:10 poc:52/52 ref:3/1 qp:28 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=
bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:0 poc:224/224 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26651 QP=19.10 NAL=2 Slice:P Poc:102 I:67   P:259  SKIP:594  size=808 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:1 poc:226/226 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26652 QP=19.85 NAL=2 Slice:B Poc:98  I:20   P:279  SKIP:621  size=499 bytes
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:2 poc:228/228 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26653 QP=21.65 NAL=0 Slice:B Poc:96  I:10   P:211  SKIP:699  size=266 bytes
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:3 poc:230/230 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26654 QP=21.67 NAL=0 Slice:B Poc:100 I:7    P:229  SKIP:684  size=283 bytes
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:4 poc:232/232 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26655 QP=18.94 NAL=2 Slice:P Poc:110 I:101  P:229  SKIP:590  size=817 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d369380] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d369380] slice:1 F mb:0 P fix frame:5 poc:234/234 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26656 QP=19.19 NAL=2 Slice:B Poc:106 I:15   P:303  SKIP:602  size=452 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d3a61c0] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [h264 @ 0x5b023d3a61c0] slice:1 F mb:0 P fix frame:6 poc:236/236 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26657 QP=22.01 NAL=0 Slice:B Poc:104 I:4    P:211  SKIP:705  size=226 bytes
# [h264 @ 0x5b023d2f5740] nal_unit_type: 1(Coded slice of a non-IDR picture), nal_ref_idc: 2
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [h264 @ 0x5b023d2f5740] slice:1 F mb:0 P fix frame:7 poc:238/238 ref:3/1 qp:17 loop:1:0:0 weight:0
# [libx264 @ 0x5b023d3a0680] frame=26658 QP=17.00 NAL=0 Slice:B Poc:108 I:5    P:220  SKIP:695  size=232 bytes
# [aac @ 0x5b023d2a64c0] FILL:
#     Last message repeated 1 times
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [libx264 @ 0x5b023d3a0680] frame=26659 QP=18.04 NAL=2 Slice:P Poc:116 I:105  P:175  SKIP:640  size=768 bytes
# [Parsed_subtitles_0 @ 0x5b023d32df40] Copying data in avfilter.
# [libx264 @ 0x5b023d3a0680] frame=26660 QP=21.48 NAL=2 Slice:B Poc:112 I:7    P:204  SKIP:709  size=288 bytes
# [out_0_0 @ 0x5b023d821c00] EOF on sink link out_0_0:default.
# [out_0_1 @ 0x5b023d820300] EOF on sink link out_0_1:default.
# No more output streams to write to, finishing.
# [libx264 @ 0x5b023d3a0680] scene cut at 26704 Icost:9418 Pcost:9086 ratio:0.0353 bias:0.2031 gop:101 (imb:780 pmb:18)
# [libx264 @ 0x5b023d3a0680] frame=26661 QP=20.24 NAL=0 Slice:B Poc:114 I:5    P:114  SKIP:801  size=171 bytes
# [libx264 @ 0x5b023d3a0680] frame=26662 QP=16.05 NAL=2 Slice:P Poc:124 I:168  P:105  SKIP:647  size=1024 bytes
# [libx264 @ 0x5b023d3a0680] frame=26663 QP=18.28 NAL=2 Slice:B Poc:120 I:20   P:204  SKIP:696  size=381 bytes
# [libx264 @ 0x5b023d3a0680] frame=26664 QP=17.00 NAL=0 Slice:B Poc:118 I:6    P:168  SKIP:746  size=182 bytes
# [libx264 @ 0x5b023d3a0680] frame=26665 QP=22.61 NAL=0 Slice:B Poc:122 I:1    P:157  SKIP:762  size=207 bytes
# [libx264 @ 0x5b023d3a0680] frame=26666 QP=17.92 NAL=2 Slice:P Poc:128 I:53   P:140  SKIP:727  size=455 bytes
B subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.546243%
# Input file #0 (video.mp4):
#   Input stream #0:0 (video): 26708 packets read (38910800 bytes); 26708 frames decoded;
#   Input stream #0:1 (audio): 47976 packets read (13368006 bytes); 47976 frames decoded (49127424 samples);
#   Total: 74684 packets (52278806 bytes) demuxed
# Input file #1 (captions_srt_output.srt):
#   Input stream #1:0 (subtitle): 0 packets read (0 bytes);
#   Total: 0 packets (0 bytes) demuxed
# Output file #0 (output_video_with_subtitles.mp4):
#   Output stream #0:0 (video): 26708 frames encoded; 26708 packets muxed (36455112 bytes);
#   Output stream #0:1 (audio): 47976 frames encoded (49127424 samples); 47977 packets muxed (17999128 bytes);
#   Total: 74685 packets (54454240 bytes) muxed
# 74684 frames successfully decoded, 0 decoding errors
# [AVIOContext @ 0x5b023d3a3b40] Statistics: 24 seeks, 228 writeouts
# [libx264 @ 0x5b023d3a0680] frame I:117   Avg QP:15.49  size: 23007
# [libx264 @ 0x5b023d3a0680] frame P:8688  Avg QP:20.63  size:  2835
# [libx264 @ 0x5b023d3a0680] frame B:17903 Avg QP:23.55  size:   510
# [libx264 @ 0x5b023d3a0680] consecutive B-frames:  8.9%  3.6%  4.4% 83.1%
# [libx264 @ 0x5b023d3a0680] mb I  I16..4: 16.2% 44.4% 39.5%
# [libx264 @ 0x5b023d3a0680] mb P  I16..4:  0.9%  2.7%  0.9%  P16..4: 23.7%  9.9%  4.9%  0.0%  0.0%    skip:57.0%
# [libx264 @ 0x5b023d3a0680] mb B  I16..4:  0.1%  0.2%  0.0%  B16..8: 22.5%  2.0%  0.2%  direct: 1.4%  skip:73.5%  L0:46.7% L1:49.9% BI: 3.4%
# [libx264 @ 0x5b023d3a0680] 8x8 transform intra:57.6% inter:63.3%
# [libx264 @ 0x5b023d3a0680] coded y,uvDC,uvAC intra: 45.4% 53.6% 20.7% inter: 5.3% 6.0% 0.1%
# [libx264 @ 0x5b023d3a0680] i16 v,h,dc,p: 38% 30% 13% 20%
# [libx264 @ 0x5b023d3a0680] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 16% 38%  3%  3%  4%  3%  5%  4%
# [libx264 @ 0x5b023d3a0680] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 20% 14%  6%  6%  7%  7%  6%  6%
# [libx264 @ 0x5b023d3a0680] i8c dc,h,v,p: 55% 19% 20%  5%
# [libx264 @ 0x5b023d3a0680] Weighted P-Frames: Y:0.4% UV:0.1%
# [libx264 @ 0x5b023d3a0680] ref P L0: 69.7% 11.8% 13.6%  4.9%  0.0%
# [libx264 @ 0x5b023d3a0680] ref B L0: 90.7%  7.8%  1.5%
# [libx264 @ 0x5b023d3a0680] ref B L1: 96.6%  3.4%
# [libx264 @ 0x5b023d3a0680] kb/s:261.80
# [aac @ 0x5b023d3a2a40] Qavg: 485.335
# [AVIOContext @ 0x5b023d2a8180] Statistics: 52601852 bytes read, 0 seeks
# [AVIOContext @ 0x5b023d40a7c0] Statistics: 37665 bytes read, 0 seeks
# Conversion took 7.15 mins.
